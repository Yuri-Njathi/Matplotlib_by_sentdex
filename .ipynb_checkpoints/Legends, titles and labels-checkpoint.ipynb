# %%
import matplotlib.pyplot as plt

# %%
#plotting from lists.
x = [1,2,3]
y = [5,7,4]

# %%
plt.plot(x,y)
plt.xlabel('x labels')
plt.ylabel('y labels')
plt.title('Basic Interesting Graph')
plt.show()
